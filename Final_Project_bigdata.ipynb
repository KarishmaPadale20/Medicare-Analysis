# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/karis/medicare.csv', low_memory=False)

# %%
df.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
# 2                    1003000142                                      KHALIL
# 3                    1003000407                                     GIRARDI
# 4                    1003000423                                     VELOTTA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
# 2                     RASHID                            NaN
# 3                      DAVID                              J
# 4                   JENNIFER                              A
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# ...

# %%
df.shape
# Out:
# (1053958, 70)

# %%
df.isna().sum()
# Out:
# National Provider Identifier                                                                   0
# Last Name/Organization Name of the Provider                                                   20
# First Name of the Provider                                                                 62608
# Middle Initial of the Provider                                                            336578
# Credentials of the Provider                                                               103570
# Gender of the Provider                                                                     62596
# Entity Type of the Provider                                                                    0
# Street Address 1 of the Provider                                                               1
# Street Address 2 of the Provider                                                          639478
# City of the Provider                                                                           1
# ...

# %%
df.isnull()
# Out:
#          National Provider Identifier  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# 5                               False
# 6                               False
# 7                               False
# 8                               False
# 9                               False
# 10                              False
# 11                              False
# 12                              False
# 13                              False
# 14                              False
# 15                              False
# 16                              False
# 17                              False
# 18                              False
# 19                              False
# 20                              False
# 21                              False
# 22                              False
# ...

# %%
df.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
# 2                    1003000142                                      KHALIL
# 3                    1003000407                                     GIRARDI
# 4                    1003000423                                     VELOTTA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
# 2                     RASHID                            NaN
# 3                      DAVID                              J
# 4                   JENNIFER                              A
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# ...

# %%
new_df = df[['Last Name/Organization Name of the Provider','Gender of the Provider','Entity Type of the Provider','City of the Provider',
            'State Code of the Provider','Country Code of the Provider','Medicare Participation Indicator','Number of Medicare Beneficiaries'
           ,'Total Medicare Allowed Amount','Total Medicare Payment Amount','Total Submitted Charge Amount']]

# %%
new_df.head()
# Out:
#   Last Name/Organization Name of the Provider Gender of the Provider  \
# 0                                   ENKESHAFI                      M
# 1                                      CIBULL                      M
# 2                                      KHALIL                      M
# 3                                     GIRARDI                      M
# 4                                     VELOTTA                      F
#
#   Entity Type of the Provider City of the Provider State Code of the Provider  \
# 0                           I           CUMBERLAND                         MD
# 1                           I             EVANSTON                         IL
# 2                           I               TOLEDO                         OH
# 3                           I           BROOKVILLE                         PA
# 4                           I            CLEVELAND                         OH
#
#   Country Code of the Provider Medicare Participation Indicator  \
# ...

# %%
new_df.isnull().sum()
# Out:
# Last Name/Organization Name of the Provider       20
# Gender of the Provider                         62596
# Entity Type of the Provider                        0
# City of the Provider                               1
# State Code of the Provider                         0
# Country Code of the Provider                       0
# Medicare Participation Indicator                   0
# Number of Medicare Beneficiaries                   0
# Total Medicare Allowed Amount                      0
# Total Medicare Payment Amount                      0
# Total Submitted Charge Amount                      0
# dtype: int64

# %%
dff = new_df.fillna(method='ffill')

# %%
dff.head()
# Out:
#   Last Name/Organization Name of the Provider Gender of the Provider  \
# 0                                   ENKESHAFI                      M
# 1                                      CIBULL                      M
# 2                                      KHALIL                      M
# 3                                     GIRARDI                      M
# 4                                     VELOTTA                      F
#
#   Entity Type of the Provider City of the Provider State Code of the Provider  \
# 0                           I           CUMBERLAND                         MD
# 1                           I             EVANSTON                         IL
# 2                           I               TOLEDO                         OH
# 3                           I           BROOKVILLE                         PA
# 4                           I            CLEVELAND                         OH
#
#   Country Code of the Provider Medicare Participation Indicator  \
# ...

# %%
dff.isna().sum()
# Out:
# Last Name/Organization Name of the Provider    0
# Gender of the Provider                         0
# Entity Type of the Provider                    0
# City of the Provider                           0
# State Code of the Provider                     0
# Country Code of the Provider                   0
# Medicare Participation Indicator               0
# Number of Medicare Beneficiaries               0
# Total Medicare Allowed Amount                  0
# Total Medicare Payment Amount                  0
# Total Submitted Charge Amount                  0
# dtype: int64

# %%
dff.to_csv('out.csv')
